# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
print('Modules are imported ')
# Out:
# Modules are imported

# %% [markdown]
# Importing Covid19 dataset

# %%
corona_dataset_csv =  pd. read_csv(r"D:\Datasets\covid19_Confirmed_dataset.csv")

# %%
corona_dataset_csv
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/2020  \
# 0              NaN            Afghanistan  33.000000  65.000000          0
# 1              NaN                Albania  41.153300  20.168300          0
# 2              NaN                Algeria  28.033900   1.659600          0
# 3              NaN                Andorra  42.506300   1.521800          0
# 4              NaN                 Angola -11.202700  17.873900          0
# ..             ...                    ...        ...        ...        ...
# 261            NaN         Western Sahara  24.215500 -12.885800          0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081          0
# 263            NaN                  Yemen  15.552727  48.516388          0
# 264            NaN                Comoros -11.645500  43.333300          0
# 265            NaN             Tajikistan  38.861034  71.276093          0
#
# ...

# %%
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/2020  1/23/2020  \
# 0            NaN    Afghanistan  33.0000  65.0000          0          0
# 1            NaN        Albania  41.1533  20.1683          0          0
# 2            NaN        Algeria  28.0339   1.6596          0          0
# 3            NaN        Andorra  42.5063   1.5218          0          0
# 4            NaN         Angola -11.2027  17.8739          0          0
#
#    1/24/2020  1/25/2020  1/26/2020  1/27/2020  ...  4/21/2020  4/22/2020  \
# 0          0          0          0          0  ...       1092       1176
# 1          0          0          0          0  ...        609        634
# 2          0          0          0          0  ...       2811       2910
# 3          0          0          0          0  ...        717        723
# 4          0          0          0          0  ...         24         25
#
#    4/23/2020  4/24/2020  4/25/2020  4/26/2020  4/27/2020  4/28/2020  \
# ...

# %%
corona_dataset_csv.shape
# Out:
# (266, 104)

# %%
#Delete Useless coloum

# %%
corona_dataset_csv.drop(["Lat","Long"],axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 corona_dataset_csv.drop(["Lat","Long"],axis=1,inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
# ...

# %%
corona_dataset_csv
# Out:
#     Province/State         Country/Region  1/22/2020  1/23/2020  1/24/2020  \
# 0              NaN            Afghanistan          0          0          0
# 1              NaN                Albania          0          0          0
# 2              NaN                Algeria          0          0          0
# 3              NaN                Andorra          0          0          0
# 4              NaN                 Angola          0          0          0
# ..             ...                    ...        ...        ...        ...
# 261            NaN         Western Sahara          0          0          0
# 262            NaN  Sao Tome and Principe          0          0          0
# 263            NaN                  Yemen          0          0          0
# 264            NaN                Comoros          0          0          0
# 265            NaN             Tajikistan          0          0          0
#
# ...

# %% [markdown]
# Aggregate all the rows by country name

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17956\2086399234.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()

# %%
corona_dataset_aggregated
# Out:
#                     1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  \
# Country/Region
# Afghanistan                 0          0          0          0          0
# Albania                     0          0          0          0          0
# Algeria                     0          0          0          0          0
# Andorra                     0          0          0          0          0
# Angola                      0          0          0          0          0
# ...                       ...        ...        ...        ...        ...
# West Bank and Gaza          0          0          0          0          0
# Western Sahara              0          0          0          0          0
# Yemen                       0          0          0          0          0
# Zambia                      0          0          0          0          0
# Zimbabwe                    0          0          0          0          0
#
# ...

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  \
# Country/Region
# Afghanistan                  0          0          0          0          0
# Albania                      0          0          0          0          0
# Algeria                      0          0          0          0          0
# Andorra                      0          0          0          0          0
# Angola                       0          0          0          0          0
# Antigua and Barbuda          0          0          0          0          0
# Argentina                    0          0          0          0          0
# Armenia                      0          0          0          0          0
# Australia                    0          0          0          0          4
# Austria                      0          0          0          0          0
#
#                      1/27/2020  1/28/2020  1/29/2020  1/30/2020  1/31/2020  \
# Country/Region
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
#  Visualize data related to a country for example chaina

# %%
corona_dataset_aggregated.loc["China"].plot()
# Out:
# <Axes: >

# %%
#comparing two counteries 
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
plt.legend()

# %%
corona_dataset_aggregated.loc["China"][:3].plot()
# Out:
# <Axes: >

# %% [raw]
# Calculatating and ploting the first deviation of the curve

# %%
corona_dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# Find Maximum Infection rate for China, Italy and Spain

# %%
corona_dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
corona_dataset_aggregated.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
corona_dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %% [markdown]
# Find Maximum Ifection rate for all of the countries

# %%
countries = list(corona_dataset_aggregated.index)
max_infections_rates = []
for c in countries: 
    max_infections_rates.append(corona_dataset_aggregated.loc[c].diff().max())
    
max_infections_rates
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
corona_dataset_aggregated["max_infections_rates"] = max_infections_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  \
# Country/Region
# Afghanistan             0          0          0          0          0
# Albania                 0          0          0          0          0
# Algeria                 0          0          0          0          0
# Andorra                 0          0          0          0          0
# Angola                  0          0          0          0          0
#
#                 1/27/2020  1/28/2020  1/29/2020  1/30/2020  1/31/2020  ...  \
# Country/Region                                                         ...
# Afghanistan             0          0          0          0          0  ...
# Albania                 0          0          0          0          0  ...
# Algeria                 0          0          0          0          0  ...
# Andorra                 0          0          0          0          0  ...
# Angola                  0          0          0          0          0  ...
#
# ...

# %% [markdown]
# Craete a Dataframe ( New) with only nedded column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infections_rates"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'max_infections_rates'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
max_infections_rates = corona_dataset_aggregated["data"]["max_infections_rates"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 max_infections_rates = corona_dataset_aggregated["data"]["max_infections_rates"]
#
# KeyError: 'data'

# %%
corona_data = pd.DataFrame({"max_infections_rates": max_infections_rates})

# %%
print(corona_data)
# Out:
#      max_infections_rates
# 0                   232.0
# 1                    34.0
# 2                   199.0
# 3                    43.0
# 4                     5.0
# ..                    ...
# 182                  66.0
# 183                   4.0
# 184                   5.0
# 185                   9.0
# 186                   8.0
#
# [187 rows x 1 columns]
